# %%
import pandas as pd

# %%
df=pd.read_csv("./../example_gyro_data.csv")

# %%
from matplotlib import pyplot as plt

# %%
df
# Out:
#     18:05:33.586  0.241814  0.136469  0.000000  0.000000.1  0.007461  \
# 0   18:05:33.993  0.241814  0.146046       0.0         0.0  0.006928
# 1   18:05:34.377  0.220267  0.126893       0.0         0.0  0.006928
# 2   18:05:34.785  0.232238  0.134075       0.0         0.0  0.004796
# 3   18:05:35.193  0.210690  0.129287       0.0         0.0  0.006129
# 4   18:05:35.562  0.215478  0.146046       0.0         0.0  0.005596
# ..           ...       ...       ...       ...         ...       ...
# 71  18:06:02.373  0.186748  0.126893       0.0         0.0  0.004796
# 72  18:06:02.786  0.196325  0.124498       0.0         0.0  0.004263
# 73  18:06:03.162  0.203507  0.124498       0.0         0.0  0.010126
# 74  18:06:03.598  0.193930  0.136469       0.0         0.0  0.010392
# 75  18:06:03.967  0.198719  0.134075       0.0         0.0  0.006129
#
#     0.000000.2  0.000000.3  0.000000.4  13.959412
# 0     0.000000       0.000       0.000  13.950588
# ...

# %%
plt.plot(df[df.columns[1:-1]])
